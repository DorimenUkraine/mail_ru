# %% [markdown]
# Для данной задачи вам предстоит построить рекомендательную систему баннеров на основе логов просмотров и лайков.
#
# Логи представлены четырьмя колонками:
#
# user_id (идентификатор пользователя),<br />
# item_id (идентификатор баннера),<br />
# like (флаг понравился ли пользователю баннер),<br />
# timestamp (unix время в секундах совершения действия).
#
# Кроме того, для пользователей и баннеров имеются признаки размерностью 32.
#
# Вам необходимо предсказать 20 баннеров для пользователей. Качество решения будет оцениваться как доля "лайкнутых" пользователей баннеров из предложенного вами списка (top-20 accuracy).

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import f_classif, mutual_info_classif

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Useful functions

# %%
def get_boxplot(column):
    
    # plot boxplots for numerical features
    
    fig, ax = plt.subplots(figsize=(14, 4))
    sns.boxplot(x='1', y=column,
                data=data,
                ax=ax, showmeans=True)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()
    
def vis_importance(xcol, ycol):
    
    # plot histograms for categorical features to visualize
    # dependence on target variable
    # xcol - feature to explore, ycol - target variable
    
    pd.crosstab(data[xcol], data[ycol]).plot(kind='bar')
    plt.title('Default frequency for {}'.format(xcol))
    plt.xlabel(xcol)
    plt.ylabel('Frequency of default')
    plt.show()
    
def outliers_detection(data, col):
    
    # detect outliers in data[col]
    
    perc25 = data[col].quantile(0.25)
    perc75 = data[col].quantile(0.75)
    IQR = perc75 - perc25
    left = perc25 - 1.5 * IQR
    right = perc75 + 1.5 * IQR
    print('min: {0}, max: {1}'.format(data[col].min(), data[col].max()))
    print('outlier boundaries: [{0}, {1}]'.format(left, right))
    if len(data[~data[col].between(left, right)]) > 0:
        print('ratio of outliers: {}'.format(len(data[(~data[col].between(left, right))&(~data[col].isna())])/len(data)))

def drop_outliers(data, col):
    
    # detect outliers in data[col]
    
    perc25 = data[col].quantile(0.25)
    perc75 = data[col].quantile(0.75)
    IQR = perc75 - perc25
    return data[(data[col].between(perc25 - 1.5 * IQR, perc75 + 1.5 * IQR))|(data[col].isna())]

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv('input/train_2.csv')
test = pd.read_csv('input/test_2.csv')
user_features = pd.read_csv('input/user-features_2.csv')
item_features = pd.read_csv('input/item-features_2.csv')

# %% [markdown]
# Описание файлов
#
# test.csv — тестовый файл, содержащий идентификаторы пользователи, для которых необходимо сделать предсказания
#
# train.csv — обучающий датасет
#
# item-features.csv — признаки для баннеров
#
# user-features — признаки для пользователей
#
# sample-submission.csv — пример решения (сабмита).

# %%
train.shape, test.shape, user_features.shape, item_features.shape
# Out:
# ((8674, 4), (497, 2), (497, 33), (444, 33))

# %%
test.info(), train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    497 non-null    int64
#  1   timestamp  497 non-null    int64
# dtypes: int64(2)
# memory usage: 7.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8674 entries, 0 to 8673
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    8674 non-null   int64
#  1   item_id    8674 non-null   int64
#  2   like       8674 non-null   int64
#  3   timestamp  8674 non-null   int64
# dtypes: int64(4)
# memory usage: 271.2 KB
# (None, None)

# %% [markdown]
# ### Data Analize

# %%
train_full = train.merge(user_features, how='left', left_on='user_id', right_on='user_id')
train_full = train_full.merge(item_features, how='left', left_on='item_id', right_on='item_id')

# %%
train_full.sample(5)
# Out:
#       user_id  item_id  like   timestamp       0_x       1_x       2_x  \
# 8254      426      369     0  1491199108  0.002198 -0.004974 -0.004648
# 491        60       57     0  1490951455  0.002026 -0.004586 -0.004285
# 5622      181      264     0  1491112780  0.001253 -0.002836 -0.002650
# 4997       31       41     0  1491091916  0.002530 -0.005726 -0.005350
# 5561      246      391     0  1491110567  0.000695 -0.001573 -0.001470
#
#            3_x       4_x       5_x  ...      22_y      23_y      24_y  \
# 8254  0.006595 -0.001574  0.002166  ... -0.002098 -0.000349  0.000561
# 491   0.006080 -0.001451  0.001997  ... -0.007565 -0.001259  0.002022
# 5622  0.003759 -0.000897  0.001235  ... -0.004196 -0.000698  0.001121
# 4997  0.007591 -0.001812  0.002494  ... -0.010062 -0.001674  0.002689
# 5561  0.002085 -0.000498  0.000685  ... -0.003634 -0.000605  0.000971
#
#           25_y      26_y      27_y      28_y      29_y      30_y      31_y
# 8254 -0.000540 -0.000996 -0.000996  0.000211 -0.000584 -0.000584  0.000149
# 491  -0.001946 -0.003592 -0.003592  0.000762 -0.002106 -0.002106  0.000536
# 5622 -0.001079 -0.001993 -0.001993  0.000422 -0.001168 -0.001168  0.000297
# 4997 -0.002589 -0.004778 -0.004778  0.001013 -0.002801 -0.002801  0.000713
# 5561 -0.000935 -0.001726 -0.001726  0.000366 -0.001012 -0.001012  0.000258
#
# [5 rows x 68 columns]

# %% [markdown]
# ### Feature Engineers

# %%
# convert to datetime

train_full['created'] = pd.to_datetime(train_full['timestamp'],unit='s')

# %%
# create new date features

train_full['created_month'] = train_full['created'].dt.month
train_full['created_day'] = train_full['created'].dt.day
train_full['created_dayofweek'] = train_full['created'].dt.dayofweek
train_full['created_hour'] = train_full['created'].dt.round('H').dt.hour

def f(x):
    if (x > 4) and (x <= 8):
        return 'Early Morning'
    elif (x > 8) and (x <= 12 ):
        return 'Morning'
    elif (x > 12) and (x <= 16):
        return'Noon'
    elif (x > 16) and (x <= 20) :
        return 'Eve'
    elif (x > 20) and (x <= 24):
        return'Night'
    elif (x <= 4):
        return'Late Night'
    
    
train_full['part_of_day'] = train_full['created_hour'].apply(f)

# train_full = train_full.drop(['created', 'timestamp'], axis=1)

# %%
train_full.sample(5)
# Out:
#       user_id  item_id  like   timestamp       0_x       1_x       2_x  \
# 363       336      138     0  1490947649  0.002198 -0.004974 -0.004648
# 646       191      143     0  1490956405  0.000602 -0.001362 -0.001273
# 8211      444      107     0  1491197808  0.004803 -0.010870 -0.010157
# 725       412        8     0  1490958931  0.002198 -0.004974 -0.004648
# 3383      133      223     0  1491041014  0.000602 -0.001362 -0.001273
#
#            3_x       4_x       5_x  ...      28_y      29_y      30_y  \
# 363   0.006595 -0.001574  0.002166  ...  0.000968 -0.002677 -0.002677
# 646   0.001806 -0.000431  0.000593  ...  0.000559 -0.001545 -0.001545
# 8211  0.014410 -0.003440  0.004734  ...  0.000762 -0.002106 -0.002106
# 725   0.006595 -0.001574  0.002166  ...  0.000597 -0.001652 -0.001652
# 3383  0.001806 -0.000431  0.000593  ...  0.000422 -0.001168 -0.001168
#
#           31_y             created  created_month  created_day  \
# 363   0.000681 2017-03-31 08:07:29              3           31
# 646   0.000393 2017-03-31 10:33:25              3           31
# 8211  0.000536 2017-04-03 05:36:48              4            3
# 725   0.000421 2017-03-31 11:15:31              3           31
# 3383  0.000297 2017-04-01 10:03:34              4            1
#
#       created_dayofweek  created_hour    part_of_day
# 363                   4             8  Early Morning
# 646                   4            11        Morning
# 8211                  0             6  Early Morning
# 725                   4            11        Morning
# 3383                  5            10        Morning
#
# [5 rows x 74 columns]

# %%
train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8674 entries, 0 to 8673
# Data columns (total 72 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            8674 non-null   int64
#  1   item_id            8674 non-null   int64
#  2   like               8674 non-null   int64
#  3   0_x                8674 non-null   float64
#  4   1_x                8674 non-null   float64
#  5   2_x                8674 non-null   float64
#  6   3_x                8674 non-null   float64
#  7   4_x                8674 non-null   float64
#  8   5_x                8674 non-null   float64
#  9   6_x                8674 non-null   float64
#  10  7_x                8674 non-null   float64
#  11  8_x                8674 non-null   float64
#  12  9_x                8674 non-null   float64
#  13  10_x               8674 non-null   float64
#  14  11_x               8674 non-null   float64
#  15  12_x               8674 non-null   float64
#  16  13_x               8674 non-null   float64
#  17  14_x               8674 non-null   float64
#  18  15_x               8674 non-null   float64
#  19  16_x               8674 non-null   float64
#  20  17_x               8674 non-null   float64
#  21  18_x               8674 non-null   float64
#  22  19_x               8674 non-null   float64
#  23  20_x               8674 non-null   float64
#  24  21_x               8674 non-null   float64
#  25  22_x               8674 non-null   float64
#  26  23_x               8674 non-null   float64
#  27  24_x               8674 non-null   float64
#  28  25_x               8674 non-null   float64
#  29  26_x               8674 non-null   float64
#  30  27_x               8674 non-null   float64
#  31  28_x               8674 non-null   float64
#  32  29_x               8674 non-null   float64
#  33  30_x               8674 non-null   float64
#  34  31_x               8674 non-null   float64
#  35  0_y                8674 non-null   float64
#  36  1_y                8674 non-null   float64
#  37  2_y                8674 non-null   float64
#  38  3_y                8674 non-null   float64
#  39  4_y                8674 non-null   float64
#  40  5_y                8674 non-null   float64
#  41  6_y                8674 non-null   float64
#  42  7_y                8674 non-null   float64
#  43  8_y                8674 non-null   float64
#  44  9_y                8674 non-null   float64
#  45  10_y               8674 non-null   float64
#  46  11_y               8674 non-null   float64
#  47  12_y               8674 non-null   float64
#  48  13_y               8674 non-null   float64
#  49  14_y               8674 non-null   float64
#  50  15_y               8674 non-null   float64
#  51  16_y               8674 non-null   float64
#  52  17_y               8674 non-null   float64
#  53  18_y               8674 non-null   float64
#  54  19_y               8674 non-null   float64
#  55  20_y               8674 non-null   float64
#  56  21_y               8674 non-null   float64
#  57  22_y               8674 non-null   float64
#  58  23_y               8674 non-null   float64
#  59  24_y               8674 non-null   float64
#  60  25_y               8674 non-null   float64
#  61  26_y               8674 non-null   float64
#  62  27_y               8674 non-null   float64
#  63  28_y               8674 non-null   float64
#  64  29_y               8674 non-null   float64
#  65  30_y               8674 non-null   float64
#  66  31_y               8674 non-null   float64
#  67  created_month      8674 non-null   int64
#  68  created_day        8674 non-null   int64
#  69  created_dayofweek  8674 non-null   int64
#  70  created_hour       8674 non-null   int64
#  71  part_of_day        8674 non-null   object
# dtypes: float64(64), int64(7), object(1)
# memory usage: 4.8+ MB

# %%
# columns by types

num_col = ['user_id', 'item_id', '0_x', '1_x',
          '2_x', '3_x', '4_x', '5_x', '6_x', '7_x',
          '8_x', '9_x', '10_x', '11_x', '12_x', '13_x',
          '14_x', '15_x', '16_x', '17_x', '18_x', '19_x',
          '21_x', '22_x', '23_x', '24_x', '25_x', '26_x',
          '27_x', '28_x', '29_x', '30_x', '31_x', '0_y', '1_y',
          '2_y', '3_y', '4_y', '5_y', '6_y', '7_y',
          '8_y', '9_y', '10_y', '11_y', '12_y', '13_y',
          '14_y', '15_y', '16_y', '17_y', '18_y', '19_y',
          '21_y', '22_y', '23_y', '24_y', '25_y', '26_y',
          '27_y', '28_y', '29_y', '30_y', '31_y']
cat_col = ['part_of_day', 'created_hour', 'created_dayofweek', 'created_day', 'created_month']
bin_col = ['like']

# %% [markdown]
# ### Analytics

# %%
train_full['item_id'].nunique()
# Out:
# 444

# %%
# На первых же занятиях по анализу данных, один из приёмов, которым я учу студентов — построение диаграммы рассеивания (скатерплот) по признакам id (номер в таблице) и время (номер, когда сделана запись).
# https://dyakonov.org/2016/07/27/id-%d0%b8-%d0%b2%d1%80%d0%b5%d0%bc%d1%8f/
# Если нам нужно совместить на графике несколько качественных и количественных показателей, то датафрейм следует предварительно обработать.

train_full.pivot_table(values = ['like'], 
               index = 'created_dayofweek', 
               aggfunc = 'sum').plot(kind = 'bar', figsize=(5, 5))

train_full.pivot_table(values = ['like'], 
               index = 'created_hour', 
               aggfunc = 'sum').plot(kind = 'bar', figsize=(5, 5))

train_full.pivot_table(values = ['like'], 
               index = 'item_id', 
               aggfunc = 'sum').plot(kind = 'bar', figsize=(15, 15))

# %% [markdown]
# ### Fitting Model

# %%
# Вытащим все баннера, у которых есть лайки и сгруппируем их по количеству лайков
 
top_likes = train_full.groupby(["item_id"])['like'].count().reset_index(name='Count').sort_values(by=['Count'], ascending=False)

# Возьмем 20 самых лучших баннеров (с большим числом лайков) и составим список

top_likes_banner_list = top_likes['item_id'].head(20).tolist()

# Сформируем список пользователей (тестовая выборка), для которых нужно сделать предсказание
test_user_id_list = test['user_id'].tolist()

# %%
import random

# С помощью функции будем отбирать случайных 20 баннеров из списка самых популярных
def random_choice(list):
    
    random_banner_list = []
    
    count = 0
    
    while count < 20:    
        random_banner_list.append(random.choice(list))
        count += 1
        
    return random_banner_list


len(random_choice(top_likes_banner_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-74909db4056b> in <module>
#      13
#      14
# ---> 15 len(random_choice(top_likes_banner_list))
#
# <ipython-input-11-74909db4056b> in random_choice(list)
#       7
#       8     while count < 20:
# ----> 9         random_banner_list.append(random.choice(list))
#      10         count += 1
#      11
#
# NameError: name 'random' is not defined

# %%
# Для тестов возьму срез пользователей, а не весь список
tmp = test_user_id_list[0:5]

# Словарь баннеров для пользователя
banners_for_users = {}

# Переберем по циклу всех пользователей, для которых сделать предсказание,
# и порекомендуем им баннера из ТОП-20 самых популярных (список смотри выше)
for i in test_user_id_list:
    
    random_banner_list = random_choice(top_likes_banner_list)
    
    banners_for_users[i] = random_banner_list

# %%
df_tmp = pd.DataFrame(banners_for_users)
df_tmp
# Out:
#     166  26   41   286  108  479  483  355  297  88   ...  240  388  277  169  \
# 0   178  194  402   92  143  165  154  143  143  403  ...  100  390  390  402
# 1   390  390  403  403  391    9  154  404   22  118  ...    9   44  402  403
# 2    92    9  178   44  404  402  118  154  118  403  ...  391  165  165  391
# 3   404  391   35  100  129   44   76  154  178  402  ...   35  405  178  118
# 4    44   76  194   35  100  404  390  405   44  391  ...   92  118  129  405
# 5     9  143   44   22   22  178  129  404  129  178  ...  154  194  402   22
# 6   165    9  100   44   22  391  143  402  194  118  ...  405  402  194  143
# 7    22  402  154  154  391  143  405   22   76   22  ...  391  402  118  404
# 8   118  118    9  391  154  391   22  194  404   76  ...  391  194  405  405
# 9   178   92  100  118  405   35   76  154   76  403  ...    9  402  129  402
# 10  405  100  143  391   76  178  404    9  100  100  ...   35    9  178  402
# 11  391  403  403  129  390   76  165   35  390    9  ...  402  129  100  405
# 12  100  118  390   22    9  402  404  143  391  154  ...  178    9  403  154
# 13  143  402   76   35  178  165   22  402  194  129  ...  405  129   35   92
# 14  402   76  405  405  129   44   35   92   22  404  ...   22   22  390  143
# 15  118  178  404   35   92  100  118   92   76  143  ...   92    9   35  404
# 16   92   92  390   76   35   92  390  178   76   92  ...  403   44  165  194
# 17  404  178  404  405   35   44  402  178  154   35  ...   22  178  405  154
# 18  194   35  194  143  178   76   44  143   35   76  ...  129  154  100  405
# 19  405  405   92  129  129  391  405  129   44   22  ...  402  118  391  194
#
#     155  190  181  448  124  167
# 0    44  178  194  390   35  143
# 1   143  154  154  391  143  154
# 2   100   92  391  118  402   92
# 3    22    9  178  391  178  118
# 4   165  118  143   44    9  391
# 5   402   76  194  178   35   22
# 6    76  390   44  100  129  391
# 7    44   44  165  143  391   35
# 8   404  165   44   44  100  143
# 9   402  194   92  165  403  403
# 10    9  405  404   35   92  390
# 11  100  100    9   92  165  391
# 12  194   92  165  402  403  405
# 13  391  118  165   92   22  165
# 14  154  143   44   92  143  143
# 15    9  165   76    9  100  391
# 16  194   76  405  402  118   35
# 17   92   44  100  129  405  165
# 18  154   76  403  178   44  154
# 19  129   44   76  194   76  402
#
# [20 rows x 497 columns]

# %%
# Функция перетасовки данных в столбцах

def shuffle(df, n=1, axis=0):
    df = df.copy()
    for _ in range(n):
        df.apply(np.random.shuffle, axis=axis)
        return df

# %%
# Перетасуем баннера у пользователей
new_df = shuffle(df_tmp)

# Поменяем строки и столбцы местами, чтобы удобно было экспортировать в csv
new_df_T = new_df.T

# %%
# Экспорт предсказаний в csv
pd.DataFrame(new_df_T).to_csv('input/out.csv', index=True)
